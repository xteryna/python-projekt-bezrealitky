# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url = "https://www.bezrealitky.cz/nemovitosti-byty-domy/840361-nabidka-prodej-bytu-moutnicka-brno"
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text)

# %%
soup.findAll("div", {})
# Out:
# [<div id="__next"><div class="collapse"><div class="bg-warning py-3" data-nosnippet="true"><div class="text-center container"><span class="text-caption text-center"><span>Zdá se, že došlo k problému s připojením nebo na serveru dochází k údržbě. Funkce webu může být omezena.</span></span></div></div></div><header class="Header_header__MwWvM header Header_header--bd__VZr_G bg-white"><div class="container"><div class="Header_headerHolder__9J27C"><div class="Header_headerToolbar__GR19z d-xl-none Header_headerToolbar--left__dRd8x"><div class="flex-nowrap btn-toolbar" role="toolbar"><div class="btn-group" role="group"><button class="Header_headerButton__2Gguj btn-sm btn btn-outline-dark" type="button"><span class="visually-hidden"><span>Hlavní menu</span></span><span class="Icon_icon__ZG9ss icon Icon_icon--middle__jItgN"><svg fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M18.503 15.254a.75.75 0 01.101 1.492l-.101.007h-13a.75.75 0 01-.10
# ...
